# %% [markdown]
# <a href="https://colab.research.google.com/github/sujata1606/Final-Year-Project/blob/main/Electonics_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the python libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
num=LabelEncoder()

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('Electronic Products Data.csv')

# %% [markdown]
# ***Exploratory data analysis***

# %%
#length of the data
len(df)
# Out:
# 216

# %%
#check shape of the data
df.shape
# Out:
# (216, 35)

# %%
#preview dataset
df.head(5)
# Out:
#          Timestamp             Name    Age      howoften  Changecell  \
# 0  3/30/2021 15:59         Jaypriya  18-25  Occasionally      Rarely
# 1  3/30/2021 17:20  Mahadik simran   18-25  Occasionally   Sometimes
# 2   4/1/2021 17:17            Sahil  25-35     Regularly      Rarely
# 3   4/1/2021 17:39           Sonali  18-25  Occasionally   Sometimes
# 4   4/2/2021 17:39          Namrata  25-35     Regularly  Very Often
#
#     Uselaptop Readlaunches Trynewproduct         Type         Product  \
# 0      Always   Very Often        Rarely          New      IT Devices
# 1   Sometimes    Sometimes    Very Often          New      IT Devices
# 2      Always       Always        Rarely  Refurbished  Mobile devices
# 3      Always       Always     Sometimes          New      IT Devices
# 4  Very Often   Very Often    Very Often          New      IT Devices
#
#          Item Brand(HomeAppliances) Brand(ITDevices) Brand(MobileDevices)  \
# 0      Laptop                    LG           Lenovo                Apple
# 1  Smartphone               Samsung             Dell                Nokia
# 2  Smartphone             Whirlpool           Lenovo              OnePlus
# 3      Laptop               Samsung               HP              Samsung
# 4      Laptop             Whirlpool               HP                Nokia
#
#   Price(HomeAppliances) Price(ITDevices) Price(MobileDevices)  \
# 0       50,000 - 60,000  40,000 - 50,000      30,000 - 40,000
# 1       40,000 - 50,000  30,000 - 40,000      60,000 - 70,000
# 2       40,000 - 50,000  40,000 - 50,000      20,000 - 30,000
# 3       20,000 - 30,000  20,000 - 30,000         100 - 10,000
# 4       30,000 - 40,000  60,000 - 70,000      30,000 - 40,000
#
#                            Time                          Where Compareprices  \
# 0                During the sale       In an electronics store            No
# 1                During the sale  In the exclusive brand store            No
# 2                During the sale       In an electronics store           Yes
# 3                During the sale       In an electronics store           Yes
# 4  Without the sale (Off Season)                        Online           Yes
#
#                                             Research  \
# 0  Ask a friend/colleague/family member for their...
# 1  Ask a friend/colleague/family member for his o...
# 2             Compare them with competitive products
# 3             Compare them with competitive products
# 4  Ask a friend/colleague/family member for their...
#
#   Timespend(10,000 - 30,000) Timespend(30,000 - 50,000)  \
# 0                 2 - 4 days                 1-3 months
# 1                 2 - 4 days                  5-10 days
# 2            Less than 1 day                2 - 4 weeks
# 3                  5-10 days                 2 - 4 days
# 4                2 - 4 weeks                2 - 4 weeks
#
#   Timespend(50,000 - 70,000) Timespend(70,000 - 1,00,000)    Yearlyspending  \
# 0                 1-3 months                   1-3 months   20,000 - 40,000
# 1                2 - 4 weeks                   1-3 months  Less than 10,000
# 2                2 - 4 weeks                  2 - 4 weeks   20,000 - 40,000
# 3                 2 - 4 days              Less than 1 day   20,000 - 40,000
# 4                 2 - 4 days                    5-10 days   60,000 - 80,000
#
#                  Factors       Productfeatures             Easeofuse  \
# 0  Pricing of a products        Very important        Very important
# 1   Quality of a product   Extremely important   Extremely important
# 2   Quality of a product  Moderately important  Moderately important
# 3   Quality of a product  Moderately important  Moderately important
# 4   Pricing of a product        Very important  Moderately important
#
#                Warranty Recommendationfromsomeone Salespersonrecommendation  \
# 0        Very important            Very important            Very important
# 1   Extremely important       Extremely important       Extremely important
# 2  Moderately important      Moderately important      Not at all important
# 3  Moderately important      Not at all important      Moderately important
# 4  Moderately important      Moderately important      Not at all important
#
#                      NoUseproduct  Rating                Review
# 0          Sell on as second-hand       4               Nothing
# 1          Sell on as second-hand       2  Want to purchase new
# 2          Sell on as second-hand       4               Nothing
# 3          Sell on as second-hand       5           Its amazing
# 4  Take to local recycling center       4                  Good

# %%
df.tail(10)
# Out:
#            Timestamp     Name           Age      howoften  Changecell  \
# 206  4/29/2021 17:34     Sara         25-35     Regularly  Very Often
# 207  4/29/2021 17:35   Urmila  50 and above  Occasionally      Always
# 208  4/29/2021 17:37   Kaveri         18-25     Regularly      Rarely
# 209   4/3/2021 18:39   Junior         25-35  Occasionally   Sometimes
# 210   4/4/2021 17:39    Priya         18-25  Occasionally   Sometimes
# 211   4/5/2021 17:39  Darshan         25-35     Regularly  Very Often
# 212   4/6/2021 17:39      Raj         18-25  Occasionally      Rarely
# 213   4/7/2021 17:39    Sonam         25-35     Regularly      Rarely
# 214   4/8/2021 17:39    Kajal         18-25  Occasionally   Sometimes
# 215   4/9/2021 17:39    Naman         25-35  Occasionally      Rarely
#
#       Uselaptop Readlaunches Trynewproduct         Type          Product  \
# 206      Always    Sometimes    Very Often          New   Mobile devices
# 207      Always   Very Often    Very Often          New   Mobile devices
# 208      Rarely       Rarely    Very Often  Refurbished       IT Devices
# 209      Always    Sometimes    Very Often          New  Home appliances
# 210      Always    Sometimes        Always          New       IT Devices
# 211      Always       Always     Sometimes          New       IT Devices
# 212      Always       Always        Rarely  Refurbished  Home appliances
# 213   Sometimes       Always        Rarely          New   Mobile devices
# 214  Very Often       Always        Rarely          New   Mobile devices
# 215   Sometimes       Always        Rarely          New       IT Devices
#
#                  Item Brand(HomeAppliances) Brand(ITDevices)  \
# 206        Smartphone             Whirlpool           Lenovo
# 207        Smartphone             Whirlpool           Lenovo
# 208            Laptop             Whirlpool               HP
# 209  Air conditioners                    LG               HP
# 210            Laptop               Samsung           Lenovo
# 211           Desktop                Godrej             Acer
# 212        Television               Samsung             Dell
# 213        Smartphone                    LG            Apple
# 214         Earphones                Godrej             Acer
# 215            Laptop             Whirlpool               HP
#
#     Brand(MobileDevices) Price(HomeAppliances) Price(ITDevices)  \
# 206               Realme       60,000 - 70,000  50,000 - 60,000
# 207              Samsung      More than 70,000  60,000 - 70,000
# 208               Realme       30,000 - 40,000  20,000 - 30,000
# 209              Samsung      More than 70,000  50,000 - 60,000
# 210               Realme       30,000 - 40,000  20,000 - 30,000
# 211                   HP       50,000 - 60,000  50,000 - 60,000
# 212              OnePlus      More than 70,000  30,000 - 40,000
# 213                Apple      More than 70,000  20,000 - 30,000
# 214               Realme          100 - 10,000  50,000 - 60,000
# 215                 Moto       40,000 - 50,000  30,000 - 40,000
#
#     Price(MobileDevices)                          Time   \
# 206      40,000 - 50,000                During the sale
# 207      50,000 - 60,000                During the sale
# 208      10,000 - 20,000  Without the sale (Off Season)
# 209      30,000 - 40,000                During the sale
# 210      10,000 - 20,000                During the sale
# 211      40,000 - 50,000                During the sale
# 212      40,000 - 50,000                During the sale
# 213      50,000 - 60,000                During the sale
# 214      10,000 - 20,000  Without the sale (Off Season)
# 215      30,000 - 40,000                During the sale
#
#                                                  Where Compareprices  \
# 206                                             Online           Yes
# 207               Online, In the exclusive brand store           Yes
# 208  In the exclusive brand store, In an electronic...           Yes
# 209                            In an electronics store           Yes
# 210                                             Online           Yes
# 211                                             Online           Yes
# 212                       In the exclusive brand store           Yes
# 213                                             Online           Yes
# 214                                             Online           Yes
# 215                            In an electronics store           Yes
#
#                                               Research  \
# 206  Ask a friend/colleague/family member for their...
# 207  Ask a friend/colleague/family member for their...
# 208  Ask a friend/colleague/family member for their...
# 209             Compare them with competitive products
# 210                                Read online reviews
# 211  Ask a friend/colleague/family member for his o...
# 212  Ask a friend/colleague/family member for his o...
# 213                          Find out brand reputation
# 214                                Read online reviews
# 215  Ask a friend/colleague/family member for his o...
#
#     Timespend(10,000 - 30,000) Timespend(30,000 - 50,000)  \
# 206                  5-10 days                2 - 4 weeks
# 207            Less than 1 day                 2 - 4 days
# 208                2 - 4 weeks                 1-3 months
# 209                  5-10 days                  5-10 days
# 210                 2 - 4 days                  5-10 days
# 211            Less than 1 day                2 - 4 weeks
# 212                 2 - 4 days                  5-10 days
# 213            Less than 1 day                2 - 4 weeks
# 214                  5-10 days                 1-3 months
# 215                 2 - 4 days                2 - 4 weeks
#
#     Timespend(50,000 - 70,000) Timespend(70,000 - 1,00,000)    Yearlyspending  \
# 206                 1-3 months                   1-3 months   40,000 - 60,000
# 207                2 - 4 weeks                   1-3 months   60,000 - 80,000
# 208                 1-3 months                   1-3 months   40,000 - 60,000
# 209                 1-3 months                    5-10 days   20,000 - 40,000
# 210                 1-3 months                   1-3 months   60,000 - 80,000
# 211                 1-3 months                    5-10 days   20,000 - 40,000
# 212                 2 - 4 days                    5-10 days   20,000 - 40,000
# 213                 3 - 4 days              Less than 1 day   60,000 - 80,000
# 214                 4 - 4 days                   1-3 months  Less than 10,000
# 215                 5 - 4 days                    5-10 days   20,000 - 40,000
#
#                                             Factors       Productfeatures  \
# 206          Services offered, Pricing of a product   Extremely important
# 207  Reliability of a product, Pricing of a product        Very important
# 208  Reliability of a product, Pricing of a product        Very important
# 209                            Quality of a product   Extremely important
# 210                            Quality of a product        Very important
# 211                            Quality of a product  Moderately important
# 212                        Reliability of a product   Extremely important
# 213                                Services offered   Extremely important
# 214                            Quality of a product        Very important
# 215                            Quality of a product   Extremely important
#
#                 Easeofuse              Warranty Recommendationfromsomeone  \
# 206        Very important   Extremely important      Moderately important
# 207        Very important        Very important      Moderately important
# 208   Extremely important        Very important      Moderately important
# 209  Moderately important   Extremely important            Very important
# 210  Moderately important  Moderately important      Moderately important
# 211  Moderately important        Very important      Not at all important
# 212  Moderately important        Very important      Not at all important
# 213  Moderately important        Very important      Not at all important
# 214  Moderately important   Extremely important      Moderately important
# 215  Moderately important        Very important      Not at all important
#
#     Salespersonrecommendation                    NoUseproduct  Rating  \
# 206      Not at all important          Sell on as second-hand       3
# 207      Moderately important          Sell on as second-hand       5
# 208      Moderately important          Sell on as second-hand       5
# 209      Not at all important          Sell on as second-hand       4
# 210      Moderately important          Sell on as second-hand       5
# 211      Moderately important  Take to local recycling center       3
# 212      Moderately important                Give to a friend       4
# 213      Not at all important          Sell on as second-hand       4
# 214      Not at all important          Sell on as second-hand       4
# 215      Not at all important  Take to local recycling center       4
#
#                     Review
# 206                Thank u
# 207           Good product
# 208                   Nice
# 209                 Awsome
# 210  Not want this product
# 211                   Good
# 212          Extermly good
# 213               wow.....
# 214           Good overall
# 215                Nothing

# %%
df.drop(['Timestamp', 'Name'],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#        Age      howoften Changecell   Uselaptop Readlaunches Trynewproduct  \
# 63   35-50  Occasionally     Always  Very Often    Sometimes     Sometimes
# 53   18-25  Occasionally  Sometimes      Always       Rarely     Sometimes
# 156  18-25     Regularly  Sometimes      Always   Very Often        Always
# 194  35-50  Occasionally      Never      Always   Very Often    Very Often
# 101  35-50  Occasionally      Never       Never       Rarely        Rarely
#
#             Type                     Product                      Item  \
# 63   Refurbished  IT Devices, Mobile devices  Smartphone, Refrigerator
# 53           New             Home appliances      Laptop, Refrigerator
# 156          New              Mobile devices                Smartphone
# 194          New             Home appliances              Refrigerator
# 101          New                  IT Devices                Smartphone
#
#     Brand(HomeAppliances) Brand(ITDevices) Brand(MobileDevices)  \
# 63                Samsung               HP              OnePlus
# 53                 Godrej             Dell              OnePlus
# 156             Whirlpool               HP              Samsung
# 194             Whirlpool           Lenovo                 Moto
# 101             Whirlpool           Lenovo              OnePlus
#
#     Price(HomeAppliances) Price(ITDevices) Price(MobileDevices)  \
# 63        20,000 - 30,000  30,000 - 40,000      30,000 - 40,000
# 53           100 - 10,000  30,000 - 40,000      40,000 - 50,000
# 156       50,000 - 60,000  40,000 - 50,000      30,000 - 40,000
# 194       50,000 - 60,000  40,000 - 50,000      30,000 - 40,000
# 101       30,000 - 40,000  20,000 - 30,000      10,000 - 20,000
#
#                              Time   \
# 63                 During the sale
# 53   Without the sale (Off Season)
# 156                During the sale
# 194                During the sale
# 101                During the sale
#
#                                                  Where Compareprices  \
# 63   In the exclusive brand store, In an electronic...           Yes
# 53                                              Online           Yes
# 156                                             Online           Yes
# 194  In the exclusive brand store, In an electronic...           Yes
# 101  In the exclusive brand store, In an electronic...           Yes
#
#                                               Research  \
# 63   Ask a friend/colleague/family member for their...
# 53                                 Read online reviews
# 156  Ask a friend/colleague/family member for their...
# 194  Ask a friend/colleague/family member for their...
# 101  Ask a friend/colleague/family member for their...
#
#     Timespend(10,000 - 30,000) Timespend(30,000 - 50,000)  \
# 63                   5-10 days                2 - 4 weeks
# 53             Less than 1 day                2 - 4 weeks
# 156                  5-10 days                2 - 4 weeks
# 194                  5-10 days                2 - 4 weeks
# 101                  5-10 days                2 - 4 weeks
#
#     Timespend(50,000 - 70,000) Timespend(70,000 - 1,00,000)    Yearlyspending  \
# 63                  1-3 months                   1-3 months   40,000 - 60,000
# 53                  1-3 months                   1-3 months  Less than 10,000
# 156                 1-3 months                   1-3 months   40,000 - 60,000
# 194                 1-3 months                   1-3 months   20,000 - 40,000
# 101                 1-3 months                   1-3 months   40,000 - 60,000
#
#                                             Factors       Productfeatures  \
# 63           Services offered, Pricing of a product   Extremely important
# 53           Services offered, Quality of a product  Moderately important
# 156  Reliability of a product, Quality of a product   Extremely important
# 194  Reliability of a product, Pricing of a product        Very important
# 101  Reliability of a product, Quality of a product        Very important
#
#                Easeofuse              Warranty Recommendationfromsomeone  \
# 63   Extremely important   Extremely important       Extremely important
# 53        Very important   Extremely important            Very important
# 156       Very important   Extremely important      Moderately important
# 194       Very important   Extremely important      Moderately important
# 101       Very important  Moderately important      Moderately important
#
#     Salespersonrecommendation                    NoUseproduct  Rating  \
# 63        Extremely important  Take to local recycling center       5
# 53        Extremely important                Put into storage       5
# 156      Moderately important          Sell on as second-hand       5
# 194      Moderately important          Sell on as second-hand       5
# 101      Moderately important          Sell on as second-hand       4
#
#               Review
# 63           Amazing
# 53   Quality is good
# 156             Good
# 194             Good
# 101             Nice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     216 non-null    object
#  1   Name                          216 non-null    object
#  2   Age                           216 non-null    object
#  3   howoften                      216 non-null    object
#  4   Changecell                    216 non-null    object
#  5   Uselaptop                     216 non-null    object
#  6   Readlaunches                  216 non-null    object
#  7   Trynewproduct                 216 non-null    object
#  8   Type                          216 non-null    object
#  9   Product                       216 non-null    object
#  10  Item                          216 non-null    object
#  11  Brand(HomeAppliances)         216 non-null    object
#  12  Brand(ITDevices)              216 non-null    object
#  13  Brand(MobileDevices)          216 non-null    object
#  14  Price(HomeAppliances)         216 non-null    object
#  15  Price(ITDevices)              216 non-null    object
#  16  Price(MobileDevices)          216 non-null    object
#  17  Time                          216 non-null    object
#  18  Where                         216 non-null    object
#  19  Compareprices                 216 non-null    object
#  20  Research                      216 non-null    object
#  21  Timespend(10,000 - 30,000)    216 non-null    object
#  22  Timespend(30,000 - 50,000)    216 non-null    object
#  23  Timespend(50,000 - 70,000)    216 non-null    object
#  24  Timespend(70,000 - 1,00,000)  216 non-null    object
#  25  Yearlyspending                216 non-null    object
#  26  Factors                       216 non-null    object
#  27  Productfeatures               216 non-null    object
#  28  Easeofuse                     216 non-null    object
#  29  Warranty                      216 non-null    object
#  30  Recommendationfromsomeone     216 non-null    object
#  31  Salespersonrecommendation     216 non-null    object
#  32  NoUseproduct                  216 non-null    object
#  33  Rating                        216 non-null    int64
#  34  Review                        215 non-null    object
# dtypes: int64(1), object(34)
# memory usage: 59.2+ KB

# %%
df.dtypes
# Out:
# Timestamp                       object
# Name                            object
# Age                             object
# howoften                        object
# Changecell                      object
# Uselaptop                       object
# Readlaunches                    object
# Trynewproduct                   object
# Type                            object
# Product                         object
# Item                            object
# Brand(HomeAppliances)           object
# Brand(ITDevices)                object
# Brand(MobileDevices)            object
# Price(HomeAppliances)           object
# Price(ITDevices)                object
# Price(MobileDevices)            object
# Time                            object
# Where                           object
# Compareprices                   object
# Research                        object
# Timespend(10,000 - 30,000)      object
# Timespend(30,000 - 50,000)      object
# Timespend(50,000 - 70,000)      object
# Timespend(70,000 - 1,00,000)    object
# Yearlyspending                  object
# Factors                         object
# Productfeatures                 object
# Easeofuse                       object
# Warranty                        object
# Recommendationfromsomeone       object
# Salespersonrecommendation       object
# NoUseproduct                    object
# Rating                           int64
# Review                          object
# dtype: object

# %%
df.describe(include='all')
# Out:
#              Id    Age how_often_buy Change_cell use_laptop  \
# count   216.000    216           216         216        216
# unique      NaN      4             2           5          5
# top         NaN  18-25     Regularly      Rarely     Always
# freq        NaN     84           117          62         93
# mean    107.500    NaN           NaN         NaN        NaN
# std      62.498    NaN           NaN         NaN        NaN
# min       0.000    NaN           NaN         NaN        NaN
# 25%      53.750    NaN           NaN         NaN        NaN
# 50%     107.500    NaN           NaN         NaN        NaN
# 75%     161.250    NaN           NaN         NaN        NaN
# max     215.000    NaN           NaN         NaN        NaN
#
#        Read_product_launches Try_new_products Type_of_the_product  \
# count                    216              216                 216
# unique                     5                5                   2
# top                Sometimes       Very Often                 New
# freq                      64               76                 162
# mean                     NaN              NaN                 NaN
# std                      NaN              NaN                 NaN
# min                      NaN              NaN                 NaN
# 25%                      NaN              NaN                 NaN
# 50%                      NaN              NaN                 NaN
# 75%                      NaN              NaN                 NaN
# max                      NaN              NaN                 NaN
#
#                 Product        Item Brand_of_HomeAppliances  \
# count               216         216                     216
# unique                8          36                       8
# top     Home appliances  Smartphone               Whirlpool
# freq                 68          60                     101
# mean                NaN         NaN                     NaN
# std                 NaN         NaN                     NaN
# min                 NaN         NaN                     NaN
# 25%                 NaN         NaN                     NaN
# 50%                 NaN         NaN                     NaN
# 75%                 NaN         NaN                     NaN
# max                 NaN         NaN                     NaN
#
#        Brand_of_ITdevices Brand_of_MobileDevices Price_of_HomeAppliances  \
# count                 216                    216                     216
# unique                  8                     12                       9
# top                Lenovo                 Realme         40,000 - 50,000
# freq                  102                     54                      50
# mean                  NaN                    NaN                     NaN
# std                   NaN                    NaN                     NaN
# min                   NaN                    NaN                     NaN
# 25%                   NaN                    NaN                     NaN
# 50%                   NaN                    NaN                     NaN
# 75%                   NaN                    NaN                     NaN
# max                   NaN                    NaN                     NaN
#
#        Price_of_ITDevices Price_of_MobileDevices Which_time_prefer  \
# count                 216                    216               216
# unique                  7                      8                 2
# top       30,000 - 40,000        30,000 - 40,000   During the sale
# freq                   50                     60               172
# mean                  NaN                    NaN               NaN
# std                   NaN                    NaN               NaN
# min                   NaN                    NaN               NaN
# 25%                   NaN                    NaN               NaN
# 50%                   NaN                    NaN               NaN
# 75%                   NaN                    NaN               NaN
# max                   NaN                    NaN               NaN
#
#        Where_do_you_prefer Compare_prices  \
# count                  216            216
# unique                  10              2
# top                 Online            Yes
# freq                    62            209
# mean                   NaN            NaN
# std                    NaN            NaN
# min                    NaN            NaN
# 25%                    NaN            NaN
# 50%                    NaN            NaN
# 75%                    NaN            NaN
# max                    NaN            NaN
#
#                                                  Research  \
# count                                                 216
# unique                                                 16
# top     Ask a friend/colleague/family member for their...
# freq                                                   40
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Timespend_on_10,000-30,000 Timespend_on_30,000-50,000  \
# count                         216                        216
# unique                          5                          5
# top                    2 - 4 days                  5-10 days
# freq                          102                         92
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#        Timespend_on_50,000-70,000 Timespend(70,000 - 1,00,000)  \
# count                         216                          216
# unique                          8                            5
# top                   2 - 4 weeks                   1-3 months
# freq                           91                          139
# mean                          NaN                          NaN
# std                           NaN                          NaN
# min                           NaN                          NaN
# 25%                           NaN                          NaN
# 50%                           NaN                          NaN
# 75%                           NaN                          NaN
# max                           NaN                          NaN
#
#        Yearly_spendings                                         Factors  \
# count               216                                             216
# unique                6                                              16
# top     40,000 - 60,000  Reliability of a product, Quality of a product
# freq                106                                              62
# mean                NaN                                             NaN
# std                 NaN                                             NaN
# min                 NaN                                             NaN
# 25%                 NaN                                             NaN
# 50%                 NaN                                             NaN
# 75%                 NaN                                             NaN
# max                 NaN                                             NaN
#
#            Product_features     Ease_of_use             Warranty  \
# count                   216             216                  216
# unique                    4               4                    4
# top     Extremely important  Very important  Extremely important
# freq                    103             107                  103
# mean                    NaN             NaN                  NaN
# std                     NaN             NaN                  NaN
# min                     NaN             NaN                  NaN
# 25%                     NaN             NaN                  NaN
# 50%                     NaN             NaN                  NaN
# 75%                     NaN             NaN                  NaN
# max                     NaN             NaN                  NaN
#
#        Recommendation_from_someone Sales_person_recommendation  \
# count                          216                         216
# unique                           4                           4
# top           Moderately important        Moderately important
# freq                           148                         106
# mean                           NaN                         NaN
# std                            NaN                         NaN
# min                            NaN                         NaN
# 25%                            NaN                         NaN
# 50%                            NaN                         NaN
# 75%                            NaN                         NaN
# max                            NaN                         NaN
#
#                 No_use_product      Rating Review
# count                      216  216.000000    215
# unique                       4         NaN     73
# top     Sell on as second-hand         NaN   Good
# freq                       126         NaN     45
# mean                       NaN    4.152778    NaN
# std                        NaN    0.632302    NaN
# min                        NaN    2.000000    NaN
# 25%                        NaN    4.000000    NaN
# 50%                        NaN    4.000000    NaN
# 75%                        NaN    5.000000    NaN
# max                        NaN    5.000000    NaN

# %%
#view columns name
df.columns
# Out:
# Index(['Timestamp', 'Name', 'Age', 'howoften', 'Changecell', 'Uselaptop',
#        'Readlaunches', 'Trynewproduct', 'Type', 'Product', 'Item',
#        'Brand(HomeAppliances)', 'Brand(ITDevices)', 'Brand(MobileDevices)',
#        'Price(HomeAppliances)', 'Price(ITDevices)', 'Price(MobileDevices)',
#        'Time ', 'Where', 'Compareprices', 'Research',
#        'Timespend(10,000 - 30,000)', 'Timespend(30,000 - 50,000)',
#        'Timespend(50,000 - 70,000)', 'Timespend(70,000 - 1,00,000)',
#        'Yearlyspending', 'Factors', 'Productfeatures', 'Easeofuse', 'Warranty',
#        'Recommendationfromsomeone', 'Salespersonrecommendation',
#        'NoUseproduct', 'Rating', 'Review'],
#       dtype='object')

# %% [markdown]
# **Missing Data**

# %%
df.isnull()
# Out:
#        Age  how_often_buy  Change_cell  use_laptop  Read_product_launches  \
# 0    False          False        False       False                  False
# 1    False          False        False       False                  False
# 2    False          False        False       False                  False
# 3    False          False        False       False                  False
# 4    False          False        False       False                  False
# ..     ...            ...          ...         ...                    ...
# 211  False          False        False       False                  False
# 212  False          False        False       False                  False
# 213  False          False        False       False                  False
# 214  False          False        False       False                  False
# 215  False          False        False       False                  False
#
#      Try_new_products  Type_of_the_product  Product   Item  \
# 0               False                False    False  False
# 1               False                False    False  False
# 2               False                False    False  False
# 3               False                False    False  False
# 4               False                False    False  False
# ..                ...                  ...      ...    ...
# 211             False                False    False  False
# 212             False                False    False  False
# 213             False                False    False  False
# 214             False                False    False  False
# 215             False                False    False  False
#
#      Brand_of_HomeAppliances  Brand_of_ITdevices  Brand_of_MobileDevices  \
# 0                      False               False                   False
# 1                      False               False                   False
# 2                      False               False                   False
# 3                      False               False                   False
# 4                      False               False                   False
# ..                       ...                 ...                     ...
# 211                    False               False                   False
# 212                    False               False                   False
# 213                    False               False                   False
# 214                    False               False                   False
# 215                    False               False                   False
#
#      Price_of_HomeAppliances  Price_of_ITDevices  Price_of_MobileDevices  \
# 0                      False               False                   False
# 1                      False               False                   False
# 2                      False               False                   False
# 3                      False               False                   False
# 4                      False               False                   False
# ..                       ...                 ...                     ...
# 211                    False               False                   False
# 212                    False               False                   False
# 213                    False               False                   False
# 214                    False               False                   False
# 215                    False               False                   False
#
#      Which_time_prefer  Where_do_you_prefer  Compare_prices  Research  \
# 0                False                False           False     False
# 1                False                False           False     False
# 2                False                False           False     False
# 3                False                False           False     False
# 4                False                False           False     False
# ..                 ...                  ...             ...       ...
# 211              False                False           False     False
# 212              False                False           False     False
# 213              False                False           False     False
# 214              False                False           False     False
# 215              False                False           False     False
#
#      Timespend_on_10,000-30,000  Timespend_on_30,000-50,000  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
# ..                          ...                         ...
# 211                       False                       False
# 212                       False                       False
# 213                       False                       False
# 214                       False                       False
# 215                       False                       False
#
#      Timespend_on_50,000-70,000  Timespend(70,000 - 1,00,000)  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
# ..                          ...                           ...
# 211                       False                         False
# 212                       False                         False
# 213                       False                         False
# 214                       False                         False
# 215                       False                         False
#
#      Yearly_spendings  Factors  Product_features  Ease_of_use  Warranty  \
# 0               False    False             False        False     False
# 1               False    False             False        False     False
# 2               False    False             False        False     False
# 3               False    False             False        False     False
# 4               False    False             False        False     False
# ..                ...      ...               ...          ...       ...
# 211             False    False             False        False     False
# 212             False    False             False        False     False
# 213             False    False             False        False     False
# 214             False    False             False        False     False
# 215             False    False             False        False     False
#
#      Recommendation_from_someone  Sales_person_recommendation  No_use_product  \
# 0                          False                        False           False
# 1                          False                        False           False
# 2                          False                        False           False
# 3                          False                        False           False
# 4                          False                        False           False
# ..                           ...                          ...             ...
# 211                        False                        False           False
# 212                        False                        False           False
# 213                        False                        False           False
# 214                        False                        False           False
# 215                        False                        False           False
#
#      Rating  Review
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False
# ..      ...     ...
# 211   False   False
# 212   False   False
# 213   False   False
# 214   False   False
# 215   False   False
#
# [216 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Name                            0
# Age                             0
# howoften                        0
# Changecell                      0
# Uselaptop                       0
# Readlaunches                    0
# Trynewproduct                   0
# Type                            0
# Product                         0
# Item                            0
# Brand(HomeAppliances)           0
# Brand(ITDevices)                0
# Brand(MobileDevices)            0
# Price(HomeAppliances)           0
# Price(ITDevices)                0
# Price(MobileDevices)            0
# Time                            0
# Where                           0
# Compareprices                   0
# Research                        0
# Timespend(10,000 - 30,000)      0
# Timespend(30,000 - 50,000)      0
# Timespend(50,000 - 70,000)      0
# Timespend(70,000 - 1,00,000)    0
# Yearlyspending                  0
# Factors                         0
# Productfeatures                 0
# Easeofuse                       0
# Warranty                        0
# Recommendationfromsomeone       0
# Salespersonrecommendation       0
# NoUseproduct                    0
# Rating                          0
# Review                          1
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis');

# %%
df=df.fillna(method='ffill')
df
# Out:
#       Id  Age how_often_buy Change_cell  use_laptop Read_product_launches  \
# 0      0    0  Occasionally      Rarely      Always            Very Often
# 1      1    0  Occasionally   Sometimes   Sometimes             Sometimes
# 2      2    1     Regularly      Rarely      Always                Always
# 3      3    0  Occasionally   Sometimes      Always                Always
# 4      4    1     Regularly  Very Often  Very Often            Very Often
# ..   ...  ...           ...         ...         ...                   ...
# 211  211    1     Regularly  Very Often      Always                Always
# 212  212    0  Occasionally      Rarely      Always                Always
# 213  213    1     Regularly      Rarely   Sometimes                Always
# 214  214    0  Occasionally   Sometimes  Very Often                Always
# 215  215    1  Occasionally      Rarely   Sometimes                Always
#
#     Try_new_products Type_of_the_product          Product        Item  \
# 0             Rarely                 New       IT Devices      Laptop
# 1         Very Often                 New       IT Devices  Smartphone
# 2             Rarely         Refurbished   Mobile devices  Smartphone
# 3          Sometimes                 New       IT Devices      Laptop
# 4         Very Often                 New       IT Devices      Laptop
# ..               ...                 ...              ...         ...
# 211        Sometimes                 New       IT Devices     Desktop
# 212           Rarely         Refurbished  Home appliances  Television
# 213           Rarely                 New   Mobile devices  Smartphone
# 214           Rarely                 New   Mobile devices   Earphones
# 215           Rarely                 New       IT Devices      Laptop
#
#     Brand_of_HomeAppliances Brand_of_ITdevices Brand_of_MobileDevices  \
# 0                        LG             Lenovo                  Apple
# 1                   Samsung               Dell                  Nokia
# 2                 Whirlpool             Lenovo                OnePlus
# 3                   Samsung                 HP                Samsung
# 4                 Whirlpool                 HP                  Nokia
# ..                      ...                ...                    ...
# 211                  Godrej               Acer                     HP
# 212                 Samsung               Dell                OnePlus
# 213                      LG              Apple                  Apple
# 214                  Godrej               Acer                 Realme
# 215               Whirlpool                 HP                   Moto
#
#     Price_of_HomeAppliances Price_of_ITDevices Price_of_MobileDevices  \
# 0           50,000 - 60,000    40,000 - 50,000        30,000 - 40,000
# 1           40,000 - 50,000    30,000 - 40,000        60,000 - 70,000
# 2           40,000 - 50,000    40,000 - 50,000        20,000 - 30,000
# 3           20,000 - 30,000    20,000 - 30,000           100 - 10,000
# 4           30,000 - 40,000    60,000 - 70,000        30,000 - 40,000
# ..                      ...                ...                    ...
# 211         50,000 - 60,000    50,000 - 60,000        40,000 - 50,000
# 212        More than 70,000    30,000 - 40,000        40,000 - 50,000
# 213        More than 70,000    20,000 - 30,000        50,000 - 60,000
# 214            100 - 10,000    50,000 - 60,000        10,000 - 20,000
# 215         40,000 - 50,000    30,000 - 40,000        30,000 - 40,000
#
#                  Which_time_prefer           Where_do_you_prefer  \
# 0                  During the sale       In an electronics store
# 1                  During the sale  In the exclusive brand store
# 2                  During the sale       In an electronics store
# 3                  During the sale       In an electronics store
# 4    Without the sale (Off Season)                        Online
# ..                             ...                           ...
# 211                During the sale                        Online
# 212                During the sale  In the exclusive brand store
# 213                During the sale                        Online
# 214  Without the sale (Off Season)                        Online
# 215                During the sale       In an electronics store
#
#     Compare_prices                                           Research  \
# 0               No  Ask a friend/colleague/family member for their...
# 1               No  Ask a friend/colleague/family member for his o...
# 2              Yes             Compare them with competitive products
# 3              Yes             Compare them with competitive products
# 4              Yes  Ask a friend/colleague/family member for their...
# ..             ...                                                ...
# 211            Yes  Ask a friend/colleague/family member for his o...
# 212            Yes  Ask a friend/colleague/family member for his o...
# 213            Yes                          Find out brand reputation
# 214            Yes                                Read online reviews
# 215            Yes  Ask a friend/colleague/family member for his o...
#
#     Timespend_on_10,000-30,000 Timespend_on_30,000-50,000  \
# 0                   2 - 4 days                 1-3 months
# 1                   2 - 4 days                  5-10 days
# 2              Less than 1 day                2 - 4 weeks
# 3                    5-10 days                 2 - 4 days
# 4                  2 - 4 weeks                2 - 4 weeks
# ..                         ...                        ...
# 211            Less than 1 day                2 - 4 weeks
# 212                 2 - 4 days                  5-10 days
# 213            Less than 1 day                2 - 4 weeks
# 214                  5-10 days                 1-3 months
# 215                 2 - 4 days                2 - 4 weeks
#
#     Timespend_on_50,000-70,000 Timespend(70,000 - 1,00,000)  Yearly_spendings  \
# 0                   1-3 months                   1-3 months   20,000 - 40,000
# 1                  2 - 4 weeks                   1-3 months  Less than 10,000
# 2                  2 - 4 weeks                  2 - 4 weeks   20,000 - 40,000
# 3                   2 - 4 days              Less than 1 day   20,000 - 40,000
# 4                   2 - 4 days                    5-10 days   60,000 - 80,000
# ..                         ...                          ...               ...
# 211                 1-3 months                    5-10 days   20,000 - 40,000
# 212                 2 - 4 days                    5-10 days   20,000 - 40,000
# 213                 3 - 4 days              Less than 1 day   60,000 - 80,000
# 214                 4 - 4 days                   1-3 months  Less than 10,000
# 215                 5 - 4 days                    5-10 days   20,000 - 40,000
#
#                       Factors      Product_features           Ease_of_use  \
# 0       Pricing of a products        Very important        Very important
# 1        Quality of a product   Extremely important   Extremely important
# 2        Quality of a product  Moderately important  Moderately important
# 3        Quality of a product  Moderately important  Moderately important
# 4        Pricing of a product        Very important  Moderately important
# ..                        ...                   ...                   ...
# 211      Quality of a product  Moderately important  Moderately important
# 212  Reliability of a product   Extremely important  Moderately important
# 213          Services offered   Extremely important  Moderately important
# 214      Quality of a product        Very important  Moderately important
# 215      Quality of a product   Extremely important  Moderately important
#
#                  Warranty Recommendation_from_someone  \
# 0          Very important              Very important
# 1     Extremely important         Extremely important
# 2    Moderately important        Moderately important
# 3    Moderately important        Not at all important
# 4    Moderately important        Moderately important
# ..                    ...                         ...
# 211        Very important        Not at all important
# 212        Very important        Not at all important
# 213        Very important        Not at all important
# 214   Extremely important        Moderately important
# 215        Very important        Not at all important
#
#     Sales_person_recommendation                  No_use_product  Rating  \
# 0                Very important          Sell on as second-hand       4
# 1           Extremely important          Sell on as second-hand       2
# 2          Not at all important          Sell on as second-hand       4
# 3          Moderately important          Sell on as second-hand       5
# 4          Not at all important  Take to local recycling center       4
# ..                          ...                             ...     ...
# 211        Moderately important  Take to local recycling center       3
# 212        Moderately important                Give to a friend       4
# 213        Not at all important          Sell on as second-hand       4
# 214        Not at all important          Sell on as second-hand       4
# 215        Not at all important  Take to local recycling center       4
#
#                    Review
# 0                 Nothing
# 1    Want to purchase new
# 2                 Nothing
# 3             Its amazing
# 4                    Good
# ..                    ...
# 211                  Good
# 212         Extermly good
# 213              wow.....
# 214          Good overall
# 215               Nothing
#
# [216 rows x 34 columns]

# %%
#dropping Timestamp and name column
df.drop(['Timestamp','Name'], axis=1,inplace=True)

# %%
df=df.reset_index()

# %%
#renaming columns
df.rename(columns ={
                      'index' :'Id',
                      'howoften': 'how_often_buy', 
                      'Changecell': 'Change_cell',
                      'Uselaptop' : 'use_laptop',
                      'Readlaunches' : 'Read_product_launches',
                    'Trynewproduct' : 'Try_new_products',
                    'Type': 'Type_of_the_product',
                    'Brand(HomeAppliances)' : 'Brand_of_HomeAppliances',
                    'Brand(ITDevices)' : 'Brand_of_ITdevices',
                    'Brand(MobileDevices)' : 'Brand_of_MobileDevices',
                    'Price(HomeAppliances)' : 'Price_of_HomeAppliances',
                    'Price(ITDevices)' : 'Price_of_ITDevices',
                    'Price(MobileDevices)' : 'Price_of_MobileDevices',
                    'Time ' : 'Which_time_prefer',
                    'Where' : 'Where_do_you_prefer',
                    'Compareprices' : 'Compare_prices',
                    'Timespend(10,000 - 30,000)' : 'Timespend_on_10,000-30,000',
                    'Timespend(30,000 - 50,000)' : 'Timespend_on_30,000-50,000',
                    'Timespend(50,000 - 70,000)' : 'Timespend_on_50,000-70,000',
                    'Timespend(70,000 - 1,00,000)' : 'Timespend_on_70,000-1,00,000',
                    'Yearlyspending' : 'Yearly_spendings',
                    'Productfeatures' : 'Product_features',
                    'Easeofuse' : 'Ease_of_use',
                    'Recommendationfromsomeone' : 'Recommendation_from_someone',
                    'Salespersonrecommendation' : 'Sales_person_recommendation',
                    'NoUseproduct' :'No_use_product'
                     },inplace=True
                )

# %%
df.sample(10)
# Out:
#       Id  Age  how_often_buy  Change_cell  use_laptop  Read_product_launches  \
# 75    75    3              1            4           4                      2
# 190  190    3              0            3           2                      4
# 76    76    0              0            1           2                      1
# 19    19    0              1            0           0                      0
# 179  179    1              0            3           4                      2
# 62    62    2              1            4           4                      4
# 122  122    3              1            3           3                      2
# 116  116    0              0            1           0                      1
# 34    34    1              0            0           0                      0
# 24    24    0              1            1           0                      0
#
#      Try_new_products Type_of_the_product  \
# 75                  2         Refurbished
# 190                 4                 New
# 76                  1                 New
# 19                  1                 New
# 179                 2                 New
# 62                  3                 New
# 122                 2         Refurbished
# 116                 1                 New
# 34                  0         Refurbished
# 24                  0                 New
#
#                                          Product  \
# 75                               Home appliances
# 190                               Mobile devices
# 76                                Mobile devices
# 19                                Mobile devices
# 179                                   IT Devices
# 62                               Home appliances
# 122                              Home appliances
# 116              Home appliances, Mobile devices
# 34   Home appliances, IT Devices, Mobile devices
# 24                               Home appliances
#
#                                                   Item  \
# 75                                          Television
# 190                                         Smartphone
# 76                                          Smartphone
# 19                                          Smartphone
# 179                                             Laptop
# 62                                                Oven
# 122                                         Television
# 116                             Television, Smartphone
# 34   Television, Laptop, Smartphone, Refrigerator, ...
# 24                                          Television
#
#      Brand_of_HomeAppliances  Brand_of_ITdevices  Brand_of_MobileDevices  \
# 75                         7                   6                      10
# 190                        7                   6                       3
# 76                         7                   6                      11
# 19                         4                   6                       8
# 179                        4                   6                       3
# 62                         3                   6                      10
# 122                        7                   3                       8
# 116                        7                   5                       3
# 34                         7                   3                       6
# 24                         4                   6                      10
#
#      Price_of_HomeAppliances  Price_of_ITDevices  Price_of_MobileDevices  \
# 75                         8                   6                       4
# 190                        4                   3                       2
# 76                         6                   6                       2
# 19                         0                   6                       6
# 179                        5                   4                       3
# 62                         3                   2                       3
# 122                        3                   2                       0
# 116                        6                   5                       4
# 34                         2                   3                       1
# 24                         4                   2                       2
#
#                  Which_time_prefer  \
# 75                 During the sale
# 190                During the sale
# 76                 During the sale
# 19                 During the sale
# 179                During the sale
# 62                 During the sale
# 122  Without the sale (Off Season)
# 116                During the sale
# 34                 During the sale
# 24   Without the sale (Off Season)
#
#                                    Where_do_you_prefer  Compare_prices  \
# 75   In the exclusive brand store, In an electronic...               1
# 190               Online, In the exclusive brand store               1
# 76                     Online, In an electronics store               1
# 19                                              Online               1
# 179                                             Online               1
# 62   In the exclusive brand store, In an electronic...               1
# 122                            In an electronics store               1
# 116                                             Online               1
# 34   In the exclusive brand store, In an electronic...               1
# 24                                              Online               1
#
#                                               Research  \
# 75   Ask a friend/colleague/family member for their...
# 190  Ask a friend/colleague/family member for their...
# 76   Ask a friend/colleague/family member for their...
# 19   Ask a friend/colleague/family member for their...
# 179  Ask a friend/colleague/family member for their...
# 62                           Find out brand reputation
# 122  Ask a friend/colleague/family member for their...
# 116     Read online reviews, Find out brand reputation
# 34   Ask a friend/colleague/family member for their...
# 24                                 Read online reviews
#
#      Timespend_on_10,000-30,000  Timespend_on_30,000-50,000  \
# 75                            1                           3
# 190                           1                           3
# 76                            1                           3
# 19                            1                           3
# 179                           1                           3
# 62                            1                           3
# 122                           3                           2
# 116                           1                           3
# 34                            1                           4
# 24                            1                           1
#
#      Timespend_on_50,000-70,000 Timespend_on_70,000-1,00,000)  \
# 75                            2                    1-3 months
# 190                           2                    1-3 months
# 76                            6                     5-10 days
# 19                            2                    1-3 months
# 179                           2                    1-3 months
# 62                            0                    1-3 months
# 122                           0                    1-3 months
# 116                           2                   2 - 4 weeks
# 34                            1               Less than 1 day
# 24                            6                    1-3 months
#
#     Yearly_spendings                                            Factors  \
# 75   60,000 - 80,000             Services offered, Pricing of a product
# 190  40,000 - 60,000  Reliability of a product, Pricing of a product...
# 76   20,000 - 40,000             Services offered, Pricing of a product
# 19   10,000 - 20,000                               Quality of a product
# 179  40,000 - 60,000     Reliability of a product, Pricing of a product
# 62   40,000 - 60,000         Pricing of a product, Quality of a product
# 122  40,000 - 60,000     Reliability of a product, Pricing of a product
# 116  60,000 - 80,000     Reliability of a product, Quality of a product
# 34   40,000 - 60,000  Services offered, Pricing of a product, Qualit...
# 24   40,000 - 60,000                           Reliability of a product
#
#          Product_features           Ease_of_use              Warranty  \
# 75         Very important        Very important        Very important
# 190        Very important   Extremely important  Moderately important
# 76         Very important        Very important        Very important
# 19         Very important   Extremely important   Extremely important
# 179   Extremely important        Very important        Very important
# 62         Very important        Very important   Extremely important
# 122        Very important        Very important  Moderately important
# 116   Extremely important   Extremely important   Extremely important
# 34   Not at all important  Moderately important  Moderately important
# 24         Very important        Very important   Extremely important
#
#     Recommendation_from_someone Sales_person_recommendation  \
# 75               Very important        Not at all important
# 190        Not at all important        Not at all important
# 76               Very important        Moderately important
# 19               Very important              Very important
# 179        Moderately important        Not at all important
# 62          Extremely important         Extremely important
# 122        Not at all important        Not at all important
# 116        Not at all important        Not at all important
# 34         Moderately important        Moderately important
# 24          Extremely important        Moderately important
#
#                      No_use_product  Rating          Review
# 75           Sell on as second-hand       5  Amazing review
# 190          Sell on as second-hand       5            Good
# 76                 Put into storage       5        Good one
# 19           Sell on as second-hand       5     Amazing one
# 179          Sell on as second-hand       4         Thank u
# 62   Take to local recycling center       4       Much good
# 122          Sell on as second-hand       4        Good one
# 116          Sell on as second-hand       4         So good
# 34           Sell on as second-hand       5        Nice use
# 24                 Put into storage       5   Good quality

# %%
df.head(10)
# Out:
#      Age how_often_buy Change_cell  use_laptop Read_product_launches  \
# 0  18-25  Occasionally      Rarely      Always            Very Often
# 1  18-25  Occasionally   Sometimes   Sometimes             Sometimes
# 2  25-35     Regularly      Rarely      Always                Always
# 3  18-25  Occasionally   Sometimes      Always                Always
# 4  25-35     Regularly  Very Often  Very Often            Very Often
# 5  18-25     Regularly   Sometimes   Sometimes             Sometimes
# 6  35-50  Occasionally       Never      Rarely                 Never
# 7  18-25     Regularly   Sometimes   Sometimes                Always
# 8  25-35  Occasionally      Always  Very Often             Sometimes
# 9  18-25     Regularly      Always  Very Often             Sometimes
#
#   Try_new_products Type_of_the_product          Product        Item  \
# 0           Rarely                 New       IT Devices      Laptop
# 1       Very Often                 New       IT Devices  Smartphone
# 2           Rarely         Refurbished   Mobile devices  Smartphone
# 3        Sometimes                 New       IT Devices      Laptop
# 4       Very Often                 New       IT Devices      Laptop
# 5           Always                 New   Mobile devices  Smartphone
# 6            Never         Refurbished  Home appliances  Television
# 7       Very Often                 New   Mobile devices     Airpods
# 8           Rarely                 New       IT Devices      Laptop
# 9       Very Often         Refurbished       IT Devices     Desktop
#
#   Brand_of_HomeAppliances Brand_of_ITdevices Brand_of_MobileDevices  \
# 0                      LG             Lenovo                  Apple
# 1                 Samsung               Dell                  Nokia
# 2               Whirlpool             Lenovo                OnePlus
# 3                 Samsung                 HP                Samsung
# 4               Whirlpool                 HP                  Nokia
# 5                 Samsung              Apple                  Nokia
# 6                    Sony                 HP                   Moto
# 7                 Samsung             Lenovo                  Apple
# 8                      Wh               Dell                   Moto
# 9               Whirlpool             Lenovo                  Apple
#
#   Price_of_HomeAppliances Price_of_ITDevices Price_of_MobileDevices  \
# 0         50,000 - 60,000    40,000 - 50,000        30,000 - 40,000
# 1         40,000 - 50,000    30,000 - 40,000        60,000 - 70,000
# 2         40,000 - 50,000    40,000 - 50,000        20,000 - 30,000
# 3         20,000 - 30,000    20,000 - 30,000           100 - 10,000
# 4         30,000 - 40,000    60,000 - 70,000        30,000 - 40,000
# 5         20,000 - 30,000    30,000 - 40,000        60,000 - 70,000
# 6         20,000 - 30,000    40,000 - 50,000        30,000 - 40,000
# 7         30,000 - 40,000    30,000 - 40,000        40,000 - 50,000
# 8         50,000 - 60,000    40,000 - 50,000           100 - 10,000
# 9         40,000 - 50,000       100 - 10,000        20,000 - 30,000
#
#                Which_time_prefer           Where_do_you_prefer Compare_prices  \
# 0                During the sale       In an electronics store             No
# 1                During the sale  In the exclusive brand store             No
# 2                During the sale       In an electronics store            Yes
# 3                During the sale       In an electronics store            Yes
# 4  Without the sale (Off Season)                        Online            Yes
# 5                During the sale                 Other sources            Yes
# 6  Without the sale (Off Season)       In an electronics store             No
# 7  Without the sale (Off Season)                        Online            Yes
# 8                During the sale  In the exclusive brand store            Yes
# 9                During the sale       In an electronics store             No
#
#                                             Research  \
# 0  Ask a friend/colleague/family member for their...
# 1  Ask a friend/colleague/family member for his o...
# 2             Compare them with competitive products
# 3             Compare them with competitive products
# 4  Ask a friend/colleague/family member for their...
# 5  Ask a friend/colleague/family member for their...
# 6             Compare them with competitive products
# 7                                Read online reviews
# 8                          Find out brand reputation
# 9             Compare them with competitive products
#
#   Timespend_on_10,000-30,000 Timespend_on_30,000-50,000  \
# 0                 2 - 4 days                 1-3 months
# 1                 2 - 4 days                  5-10 days
# 2            Less than 1 day                2 - 4 weeks
# 3                  5-10 days                 2 - 4 days
# 4                2 - 4 weeks                2 - 4 weeks
# 5            Less than 1 day                 2 - 4 days
# 6                2 - 4 weeks                 1-3 months
# 7            Less than 1 day                 2 - 4 days
# 8            Less than 1 day                 2 - 4 days
# 9            Less than 1 day                 2 - 4 days
#
#   Timespend_on_50,000-70,000 Timespend(70,000 - 1,00,000)  Yearly_spendings  \
# 0                 1-3 months                   1-3 months   20,000 - 40,000
# 1                2 - 4 weeks                   1-3 months  Less than 10,000
# 2                2 - 4 weeks                  2 - 4 weeks   20,000 - 40,000
# 3                 2 - 4 days              Less than 1 day   20,000 - 40,000
# 4                 2 - 4 days                    5-10 days   60,000 - 80,000
# 5                  5-10 days                   1-3 months   40,000 - 60,000
# 6                 1-3 months                   1-3 months   20,000 - 40,000
# 7                  5-10 days                  2 - 4 weeks   60,000 - 80,000
# 8                  5-10 days                   1-3 months   40,000 - 60,000
# 9                  5-10 days                   1-3 months   60,000 - 80,000
#
#                  Factors      Product_features           Ease_of_use  \
# 0  Pricing of a products        Very important        Very important
# 1   Quality of a product   Extremely important   Extremely important
# 2   Quality of a product  Moderately important  Moderately important
# 3   Quality of a product  Moderately important  Moderately important
# 4   Pricing of a product        Very important  Moderately important
# 5   Quality of a product        Very important        Very important
# 6   Quality of a product        Very important        Very important
# 7   Pricing of a product  Moderately important  Moderately important
# 8   Pricing of a product  Not at all important  Moderately important
# 9       Services offered  Moderately important  Moderately important
#
#                Warranty Recommendation_from_someone  \
# 0        Very important              Very important
# 1   Extremely important         Extremely important
# 2  Moderately important        Moderately important
# 3  Moderately important        Not at all important
# 4  Moderately important        Moderately important
# 5        Very important              Very important
# 6        Very important              Very important
# 7  Moderately important        Moderately important
# 8  Moderately important        Moderately important
# 9  Not at all important        Moderately important
#
#   Sales_person_recommendation                  No_use_product  Rating  \
# 0              Very important          Sell on as second-hand       4
# 1         Extremely important          Sell on as second-hand       2
# 2        Not at all important          Sell on as second-hand       4
# 3        Moderately important          Sell on as second-hand       5
# 4        Not at all important  Take to local recycling center       4
# 5              Very important                Give to a friend       4
# 6              Very important          Sell on as second-hand       4
# 7        Moderately important          Sell on as second-hand       4
# 8        Moderately important                Give to a friend       3
# 9              Very important          Sell on as second-hand       3
#
#                  Review
# 0               Nothing
# 1  Want to purchase new
# 2               Nothing
# 3           Its amazing
# 4                  Good
# 5                  Good
# 6                  Nice
# 7        That's awesome
# 8               So good
# 9               So nice

# %%
df
# Out:
#       Id  Age how_often_buy Change_cell  use_laptop Read_product_launches  \
# 0      0    0  Occasionally      Rarely      Always            Very Often
# 1      1    0  Occasionally   Sometimes   Sometimes             Sometimes
# 2      2    1     Regularly      Rarely      Always                Always
# 3      3    0  Occasionally   Sometimes      Always                Always
# 4      4    1     Regularly  Very Often  Very Often            Very Often
# ..   ...  ...           ...         ...         ...                   ...
# 211  211    1     Regularly  Very Often      Always                Always
# 212  212    0  Occasionally      Rarely      Always                Always
# 213  213    1     Regularly      Rarely   Sometimes                Always
# 214  214    0  Occasionally   Sometimes  Very Often                Always
# 215  215    1  Occasionally      Rarely   Sometimes                Always
#
#     Try_new_products Type_of_the_product          Product        Item  \
# 0             Rarely                 New       IT Devices      Laptop
# 1         Very Often                 New       IT Devices  Smartphone
# 2             Rarely         Refurbished   Mobile devices  Smartphone
# 3          Sometimes                 New       IT Devices      Laptop
# 4         Very Often                 New       IT Devices      Laptop
# ..               ...                 ...              ...         ...
# 211        Sometimes                 New       IT Devices     Desktop
# 212           Rarely         Refurbished  Home appliances  Television
# 213           Rarely                 New   Mobile devices  Smartphone
# 214           Rarely                 New   Mobile devices   Earphones
# 215           Rarely                 New       IT Devices      Laptop
#
#     Brand_of_HomeAppliances Brand_of_ITdevices Brand_of_MobileDevices  \
# 0                        LG             Lenovo                  Apple
# 1                   Samsung               Dell                  Nokia
# 2                 Whirlpool             Lenovo                OnePlus
# 3                   Samsung                 HP                Samsung
# 4                 Whirlpool                 HP                  Nokia
# ..                      ...                ...                    ...
# 211                  Godrej               Acer                     HP
# 212                 Samsung               Dell                OnePlus
# 213                      LG              Apple                  Apple
# 214                  Godrej               Acer                 Realme
# 215               Whirlpool                 HP                   Moto
#
#     Price_of_HomeAppliances Price_of_ITDevices Price_of_MobileDevices  \
# 0           50,000 - 60,000    40,000 - 50,000        30,000 - 40,000
# 1           40,000 - 50,000    30,000 - 40,000        60,000 - 70,000
# 2           40,000 - 50,000    40,000 - 50,000        20,000 - 30,000
# 3           20,000 - 30,000    20,000 - 30,000           100 - 10,000
# 4           30,000 - 40,000    60,000 - 70,000        30,000 - 40,000
# ..                      ...                ...                    ...
# 211         50,000 - 60,000    50,000 - 60,000        40,000 - 50,000
# 212        More than 70,000    30,000 - 40,000        40,000 - 50,000
# 213        More than 70,000    20,000 - 30,000        50,000 - 60,000
# 214            100 - 10,000    50,000 - 60,000        10,000 - 20,000
# 215         40,000 - 50,000    30,000 - 40,000        30,000 - 40,000
#
#                  Which_time_prefer           Where_do_you_prefer  \
# 0                  During the sale       In an electronics store
# 1                  During the sale  In the exclusive brand store
# 2                  During the sale       In an electronics store
# 3                  During the sale       In an electronics store
# 4    Without the sale (Off Season)                        Online
# ..                             ...                           ...
# 211                During the sale                        Online
# 212                During the sale  In the exclusive brand store
# 213                During the sale                        Online
# 214  Without the sale (Off Season)                        Online
# 215                During the sale       In an electronics store
#
#     Compare_prices                                           Research  \
# 0               No  Ask a friend/colleague/family member for their...
# 1               No  Ask a friend/colleague/family member for his o...
# 2              Yes             Compare them with competitive products
# 3              Yes             Compare them with competitive products
# 4              Yes  Ask a friend/colleague/family member for their...
# ..             ...                                                ...
# 211            Yes  Ask a friend/colleague/family member for his o...
# 212            Yes  Ask a friend/colleague/family member for his o...
# 213            Yes                          Find out brand reputation
# 214            Yes                                Read online reviews
# 215            Yes  Ask a friend/colleague/family member for his o...
#
#     Timespend_on_10,000-30,000 Timespend_on_30,000-50,000  \
# 0                   2 - 4 days                 1-3 months
# 1                   2 - 4 days                  5-10 days
# 2              Less than 1 day                2 - 4 weeks
# 3                    5-10 days                 2 - 4 days
# 4                  2 - 4 weeks                2 - 4 weeks
# ..                         ...                        ...
# 211            Less than 1 day                2 - 4 weeks
# 212                 2 - 4 days                  5-10 days
# 213            Less than 1 day                2 - 4 weeks
# 214                  5-10 days                 1-3 months
# 215                 2 - 4 days                2 - 4 weeks
#
#     Timespend_on_50,000-70,000 Timespend(70,000 - 1,00,000)  Yearly_spendings  \
# 0                   1-3 months                   1-3 months   20,000 - 40,000
# 1                  2 - 4 weeks                   1-3 months  Less than 10,000
# 2                  2 - 4 weeks                  2 - 4 weeks   20,000 - 40,000
# 3                   2 - 4 days              Less than 1 day   20,000 - 40,000
# 4                   2 - 4 days                    5-10 days   60,000 - 80,000
# ..                         ...                          ...               ...
# 211                 1-3 months                    5-10 days   20,000 - 40,000
# 212                 2 - 4 days                    5-10 days   20,000 - 40,000
# 213                 3 - 4 days              Less than 1 day   60,000 - 80,000
# 214                 4 - 4 days                   1-3 months  Less than 10,000
# 215                 5 - 4 days                    5-10 days   20,000 - 40,000
#
#                       Factors      Product_features           Ease_of_use  \
# 0       Pricing of a products        Very important        Very important
# 1        Quality of a product   Extremely important   Extremely important
# 2        Quality of a product  Moderately important  Moderately important
# 3        Quality of a product  Moderately important  Moderately important
# 4        Pricing of a product        Very important  Moderately important
# ..                        ...                   ...                   ...
# 211      Quality of a product  Moderately important  Moderately important
# 212  Reliability of a product   Extremely important  Moderately important
# 213          Services offered   Extremely important  Moderately important
# 214      Quality of a product        Very important  Moderately important
# 215      Quality of a product   Extremely important  Moderately important
#
#                  Warranty Recommendation_from_someone  \
# 0          Very important              Very important
# 1     Extremely important         Extremely important
# 2    Moderately important        Moderately important
# 3    Moderately important        Not at all important
# 4    Moderately important        Moderately important
# ..                    ...                         ...
# 211        Very important        Not at all important
# 212        Very important        Not at all important
# 213        Very important        Not at all important
# 214   Extremely important        Moderately important
# 215        Very important        Not at all important
#
#     Sales_person_recommendation                  No_use_product  Rating  \
# 0                Very important          Sell on as second-hand       4
# 1           Extremely important          Sell on as second-hand       2
# 2          Not at all important          Sell on as second-hand       4
# 3          Moderately important          Sell on as second-hand       5
# 4          Not at all important  Take to local recycling center       4
# ..                          ...                             ...     ...
# 211        Moderately important  Take to local recycling center       3
# 212        Moderately important                Give to a friend       4
# 213        Not at all important          Sell on as second-hand       4
# 214        Not at all important          Sell on as second-hand       4
# 215        Not at all important  Take to local recycling center       4
#
#                    Review
# 0                 Nothing
# 1    Want to purchase new
# 2                 Nothing
# 3             Its amazing
# 4                    Good
# ..                    ...
# 211                  Good
# 212         Extermly good
# 213              wow.....
# 214          Good overall
# 215               Nothing
#
# [216 rows x 34 columns]

# %% [markdown]
# **Converting categorical data into integer**

# %%
#1st method
df['Age'] = df['Age'].replace({ '18-25' : 0 , '25-35' :1 ,'35-50' : 2, '50 and above': 3})

# %%
df['how_often_buy'] = df['how_often_buy'].replace({ 'Regularly' : 0 , 'Occasionally': 1})
df['Change_cell'] = df['Change_cell'].replace({'Always' : 0, 'Very Often' : 1, 'Sometimes' : 2, 'Rarely': 3, 'Never' : 4})
df['use_laptop'] = df['use_laptop'].replace({'Always' : 0, 'Very Often' : 1, 'Sometimes' : 2, 'Rarely': 3, 'Never' : 4})
df['Read_product_launches'] = df['Read_product_launches'].replace({'Always' : 0, 'Very Often' : 1, 'Sometimes' : 2, 'Rarely': 3, 'Never' : 4})
df['Try_new_products'] = df['Try_new_products'].replace({'Always' : 0, 'Very Often' : 1, 'Sometimes' : 2, 'Rarely': 3, 'Never' : 4})

# %%
df['Which_time_prefer']=df['Which_time_prefer'].replace({'During the sale': 'onsale','Without the sale (Off Season)' : 'offsale' })

# %%
df
# Out:
#       Id  Age  how_often_buy  Change_cell  use_laptop  Read_product_launches  \
# 0      0    0              1            3           0                      1
# 1      1    0              1            2           2                      2
# 2      2    1              0            3           0                      0
# 3      3    0              1            2           0                      0
# 4      4    1              0            1           1                      1
# ..   ...  ...            ...          ...         ...                    ...
# 211  211    1              0            1           0                      0
# 212  212    0              1            3           0                      0
# 213  213    1              0            3           2                      0
# 214  214    0              1            2           1                      0
# 215  215    1              1            3           2                      0
#
#      Try_new_products Type_of_the_product          Product        Item  \
# 0                   3                 New       IT Devices      Laptop
# 1                   1                 New       IT Devices  Smartphone
# 2                   3         Refurbished   Mobile devices  Smartphone
# 3                   2                 New       IT Devices      Laptop
# 4                   1                 New       IT Devices      Laptop
# ..                ...                 ...              ...         ...
# 211                 2                 New       IT Devices     Desktop
# 212                 3         Refurbished  Home appliances  Television
# 213                 3                 New   Mobile devices  Smartphone
# 214                 3                 New   Mobile devices   Earphones
# 215                 3                 New       IT Devices      Laptop
#
#      Brand_of_HomeAppliances  Brand_of_ITdevices  Brand_of_MobileDevices  \
# 0                          3                   6                       0
# 1                          4                   3                       4
# 2                          7                   6                       6
# 3                          4                   5                      10
# 4                          7                   5                       4
# ..                       ...                 ...                     ...
# 211                        1                   0                       1
# 212                        4                   3                       6
# 213                        3                   2                       0
# 214                        1                   0                       8
# 215                        7                   5                       3
#
#      Price_of_HomeAppliances  Price_of_ITDevices  Price_of_MobileDevices  \
# 0                          5                   4                       3
# 1                          4                   3                       6
# 2                          4                   4                       2
# 3                          2                   2                       1
# 4                          3                   6                       3
# ..                       ...                 ...                     ...
# 211                        5                   5                       4
# 212                        8                   3                       4
# 213                        8                   2                       5
# 214                        1                   5                       0
# 215                        4                   3                       3
#
#     Which_time_prefer           Where_do_you_prefer  Compare_prices  \
# 0              onsale       In an electronics store               0
# 1              onsale  In the exclusive brand store               0
# 2              onsale       In an electronics store               1
# 3              onsale       In an electronics store               1
# 4             offsale                        Online               1
# ..                ...                           ...             ...
# 211            onsale                        Online               1
# 212            onsale  In the exclusive brand store               1
# 213            onsale                        Online               1
# 214           offsale                        Online               1
# 215            onsale       In an electronics store               1
#
#                                               Research  \
# 0    Ask a friend/colleague/family member for their...
# 1    Ask a friend/colleague/family member for his o...
# 2               Compare them with competitive products
# 3               Compare them with competitive products
# 4    Ask a friend/colleague/family member for their...
# ..                                                 ...
# 211  Ask a friend/colleague/family member for his o...
# 212  Ask a friend/colleague/family member for his o...
# 213                          Find out brand reputation
# 214                                Read online reviews
# 215  Ask a friend/colleague/family member for his o...
#
#      Timespend_on_10,000-30,000  Timespend_on_30,000-50,000  \
# 0                             1                           0
# 1                             1                           3
# 2                             4                           2
# 3                             3                           1
# 4                             2                           2
# ..                          ...                         ...
# 211                           4                           2
# 212                           1                           3
# 213                           4                           2
# 214                           3                           0
# 215                           1                           2
#
#      Timespend_on_50,000-70,000  Timespend_on_70,000-1,00,000)  \
# 0                             0                              0
# 1                             2                              0
# 2                             2                              2
# 3                             1                              4
# 4                             1                              3
# ..                          ...                            ...
# 211                           0                              3
# 212                           1                              3
# 213                           3                              4
# 214                           4                              0
# 215                           5                              3
#
#      Yearly_spendings                   Factors  Product_features  \
# 0                   1     Pricing of a products                 3
# 1                   4      Quality of a product                 0
# 2                   1      Quality of a product                 1
# 3                   1      Quality of a product                 1
# 4                   3      Pricing of a product                 3
# ..                ...                       ...               ...
# 211                 1      Quality of a product                 1
# 212                 1  Reliability of a product                 0
# 213                 3          Services offered                 0
# 214                 4      Quality of a product                 3
# 215                 1      Quality of a product                 0
#
#      Ease_of_use  Warranty  Recommendation_from_someone  \
# 0              3         3                            3
# 1              0         0                            0
# 2              1         1                            1
# 3              1         1                            2
# 4              1         1                            1
# ..           ...       ...                          ...
# 211            1         3                            2
# 212            1         3                            2
# 213            1         3                            2
# 214            1         0                            1
# 215            1         3                            2
#
#      Sales_person_recommendation  No_use_product  Rating                Review
# 0                              3               2       4               Nothing
# 1                              0               2       2  Want to purchase new
# 2                              2               2       4               Nothing
# 3                              1               2       5           Its amazing
# 4                              2               3       4                  Good
# ..                           ...             ...     ...                   ...
# 211                            1               3       3                  Good
# 212                            1               0       4         Extermly good
# 213                            2               2       4              wow.....
# 214                            2               2       4          Good overall
# 215                            2               3       4               Nothing
#
# [216 rows x 34 columns]

# %%
#2nd method
df['Brand_of_HomeAppliances']=num.fit_transform(df['Brand_of_HomeAppliances']).astype('int')
df['Brand_of_ITdevices']=num.fit_transform(df['Brand_of_ITdevices']).astype('int')
df['Brand_of_MobileDevices']=num.fit_transform(df['Brand_of_MobileDevices']).astype('int')
df['Price_of_HomeAppliances']=num.fit_transform(df['Price_of_HomeAppliances']).astype('int')
df['Price_of_ITDevices']=num.fit_transform(df['Price_of_ITDevices']).astype('int')
df['Price_of_MobileDevices']=num.fit_transform(df['Price_of_MobileDevices']).astype('int')
df['Compare_prices']=num.fit_transform(df['Compare_prices']).astype('int')
df['Timespend_on_10,000-30,000']=num.fit_transform(df['Timespend_on_10,000-30,000']).astype('int')
df['Timespend_on_30,000-50,000']=num.fit_transform(df['Timespend_on_30,000-50,000']).astype('int')
df['Timespend_on_50,000-70,000']=num.fit_transform(df['Timespend_on_50,000-70,000']).astype('int')
df['Timespend_on_70,000-1,00,000)']=num.fit_transform(df['Timespend_on_70,000-1,00,000)']).astype('int')
df['Yearly_spendings']=num.fit_transform(df['Yearly_spendings']).astype('int')
df['Product_features']=num.fit_transform(df['Product_features']).astype('int')
df['Ease_of_use']=num.fit_transform(df['Ease_of_use']).astype('int')
df['Warranty']=num.fit_transform(df['Warranty']).astype('int')
df['Recommendation_from_someone']=num.fit_transform(df['Recommendation_from_someone']).astype('int')
df['Sales_person_recommendation']=num.fit_transform(df['Sales_person_recommendation']).astype('int')
df['No_use_product']=num.fit_transform(df['No_use_product']).astype('int')

# %%
df
# Out:
#       Id  Age  how_often_buy  Change_cell  use_laptop  Read_product_launches  \
# 0      0    0              1            3           0                      1
# 1      1    0              1            2           2                      2
# 2      2    1              0            3           0                      0
# 3      3    0              1            2           0                      0
# 4      4    1              0            1           1                      1
# ..   ...  ...            ...          ...         ...                    ...
# 211  211    1              0            1           0                      0
# 212  212    0              1            3           0                      0
# 213  213    1              0            3           2                      0
# 214  214    0              1            2           1                      0
# 215  215    1              1            3           2                      0
#
#      Try_new_products Type_of_the_product          Product        Item  \
# 0                   3                 New       IT Devices      Laptop
# 1                   1                 New       IT Devices  Smartphone
# 2                   3         Refurbished   Mobile devices  Smartphone
# 3                   2                 New       IT Devices      Laptop
# 4                   1                 New       IT Devices      Laptop
# ..                ...                 ...              ...         ...
# 211                 2                 New       IT Devices     Desktop
# 212                 3         Refurbished  Home appliances  Television
# 213                 3                 New   Mobile devices  Smartphone
# 214                 3                 New   Mobile devices   Earphones
# 215                 3                 New       IT Devices      Laptop
#
#      Brand_of_HomeAppliances  Brand_of_ITdevices  Brand_of_MobileDevices  \
# 0                          3                   6                       0
# 1                          4                   3                       4
# 2                          7                   6                       6
# 3                          4                   5                      10
# 4                          7                   5                       4
# ..                       ...                 ...                     ...
# 211                        1                   0                       1
# 212                        4                   3                       6
# 213                        3                   2                       0
# 214                        1                   0                       8
# 215                        7                   5                       3
#
#      Price_of_HomeAppliances  Price_of_ITDevices  Price_of_MobileDevices  \
# 0                          5                   4                       3
# 1                          4                   3                       6
# 2                          4                   4                       2
# 3                          2                   2                       1
# 4                          3                   6                       3
# ..                       ...                 ...                     ...
# 211                        5                   5                       4
# 212                        8                   3                       4
# 213                        8                   2                       5
# 214                        1                   5                       0
# 215                        4                   3                       3
#
#                  Which_time_prefer           Where_do_you_prefer  \
# 0                  During the sale       In an electronics store
# 1                  During the sale  In the exclusive brand store
# 2                  During the sale       In an electronics store
# 3                  During the sale       In an electronics store
# 4    Without the sale (Off Season)                        Online
# ..                             ...                           ...
# 211                During the sale                        Online
# 212                During the sale  In the exclusive brand store
# 213                During the sale                        Online
# 214  Without the sale (Off Season)                        Online
# 215                During the sale       In an electronics store
#
#      Compare_prices                                           Research  \
# 0                 0  Ask a friend/colleague/family member for their...
# 1                 0  Ask a friend/colleague/family member for his o...
# 2                 1             Compare them with competitive products
# 3                 1             Compare them with competitive products
# 4                 1  Ask a friend/colleague/family member for their...
# ..              ...                                                ...
# 211               1  Ask a friend/colleague/family member for his o...
# 212               1  Ask a friend/colleague/family member for his o...
# 213               1                          Find out brand reputation
# 214               1                                Read online reviews
# 215               1  Ask a friend/colleague/family member for his o...
#
#      Timespend_on_10,000-30,000  Timespend_on_30,000-50,000  \
# 0                             1                           0
# 1                             1                           3
# 2                             4                           2
# 3                             3                           1
# 4                             2                           2
# ..                          ...                         ...
# 211                           4                           2
# 212                           1                           3
# 213                           4                           2
# 214                           3                           0
# 215                           1                           2
#
#      Timespend_on_50,000-70,000  Timespend_on_70,000-1,00,000)  \
# 0                             0                              0
# 1                             2                              0
# 2                             2                              2
# 3                             1                              4
# 4                             1                              3
# ..                          ...                            ...
# 211                           0                              3
# 212                           1                              3
# 213                           3                              4
# 214                           4                              0
# 215                           5                              3
#
#      Yearly_spendings                   Factors  Product_features  \
# 0                   1     Pricing of a products                 3
# 1                   4      Quality of a product                 0
# 2                   1      Quality of a product                 1
# 3                   1      Quality of a product                 1
# 4                   3      Pricing of a product                 3
# ..                ...                       ...               ...
# 211                 1      Quality of a product                 1
# 212                 1  Reliability of a product                 0
# 213                 3          Services offered                 0
# 214                 4      Quality of a product                 3
# 215                 1      Quality of a product                 0
#
#      Ease_of_use  Warranty  Recommendation_from_someone  \
# 0              3         3                            3
# 1              0         0                            0
# 2              1         1                            1
# 3              1         1                            2
# 4              1         1                            1
# ..           ...       ...                          ...
# 211            1         3                            2
# 212            1         3                            2
# 213            1         3                            2
# 214            1         0                            1
# 215            1         3                            2
#
#      Sales_person_recommendation  No_use_product  Rating                Review
# 0                              3               2       4               Nothing
# 1                              0               2       2  Want to purchase new
# 2                              2               2       4               Nothing
# 3                              1               2       5           Its amazing
# 4                              2               3       4                  Good
# ..                           ...             ...     ...                   ...
# 211                            1               3       3                  Good
# 212                            1               0       4         Extermly good
# 213                            2               2       4              wow.....
# 214                            2               2       4          Good overall
# 215                            2               3       4               Nothing
#
# [216 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Id                             216 non-null    int64
#  1   Age                            216 non-null    int64
#  2   how_often_buy                  216 non-null    int64
#  3   Change_cell                    216 non-null    int64
#  4   use_laptop                     216 non-null    int64
#  5   Read_product_launches          216 non-null    int64
#  6   Try_new_products               216 non-null    int64
#  7   Type_of_the_product            216 non-null    object
#  8   Product                        216 non-null    object
#  9   Item                           216 non-null    object
#  10  Brand_of_HomeAppliances        216 non-null    int64
#  11  Brand_of_ITdevices             216 non-null    int64
#  12  Brand_of_MobileDevices         216 non-null    int64
#  13  Price_of_HomeAppliances        216 non-null    int64
#  14  Price_of_ITDevices             216 non-null    int64
#  15  Price_of_MobileDevices         216 non-null    int64
#  16  Which_time_prefer              216 non-null    object
#  17  Where_do_you_prefer            216 non-null    object
#  18  Compare_prices                 216 non-null    int64
#  19  Research                       216 non-null    object
#  20  Timespend_on_10,000-30,000     216 non-null    int64
#  21  Timespend_on_30,000-50,000     216 non-null    int64
#  22  Timespend_on_50,000-70,000     216 non-null    int64
#  23  Timespend_on_70,000-1,00,000)  216 non-null    int64
#  24  Yearly_spendings               216 non-null    int64
#  25  Factors                        216 non-null    object
#  26  Product_features               216 non-null    int64
#  27  Ease_of_use                    216 non-null    int64
#  28  Warranty                       216 non-null    int64
#  29  Recommendation_from_someone    216 non-null    int64
#  30  Sales_person_recommendation    216 non-null    object
#  31  No_use_product                 216 non-null    int64
#  32  Rating                         216 non-null    int64
#  33  Review                         216 non-null    object
# dtypes: int64(25), object(9)
# memory usage: 57.5+ KB

# %% [markdown]
# **Visual exploratory data analysis**

# %%
df['Age'].value_counts()  #18-25 = 0, 25-35 = 1, 35-50 = 2, 50 and above = 3
# Out:
# 0    84
# 1    68
# 2    44
# 3    20
# Name: Age, dtype: int64

# %%
df['Timespend_on_10,000-30,000'].value_counts()
# Out:
# 1    102
# 3     65
# 4     33
# 2     14
# 0      2
# Name: Timespend_on_10,000-30,000, dtype: int64

# %%
df['Timespend_on_30,000-50,000'].value_counts()
# Out:
# 3    92
# 2    69
# 1    35
# 0    14
# 4     6
# Name: Timespend_on_30,000-50,000, dtype: int64

# %%
df['Timespend_on_70,000-1,00,000)'].value_counts()
# Out:
# 0    139
# 2     41
# 3     18
# 1     11
# 4      7
# Name: Timespend_on_70,000-1,00,000), dtype: int64

# %%
df['Yearly_spendings'].value_counts()
# Out:
# 2    106
# 3     49
# 1     37
# 0     10
# 5      9
# 4      5
# Name: Yearly_spendings, dtype: int64

# %%
df.plot(x="Yearly_spendings",y="Age",kind="barh",figsize=(30,60))
plt.show()
