# %% [markdown]
# <a href="https://colab.research.google.com/github/sujata1606/Final-Year-Project/blob/main/Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
#import the dependencies
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Ignore warnings
import warnings
warnings.simplefilter(action ="ignore", category = FutureWarning)

# %% [markdown]
# **Load the dataset**

# %%
df = pd.read_csv('Electronic Products Data.csv')

# %%
df.sample(5)
# Out:
#            Timestamp        Name  ... Rating                      Review
# 85   4/15/2021 14:29   Prabhakar  ...      4  Thanks for taking feedback
# 191  4/27/2021 19:37     Sangita  ...      4                     So good
# 20    4/1/2021 20:08  Akssh jade  ...      5                        Good
# 58     4/5/2021 0:11      Deeraj  ...      5  Thanks for taking feedback
# 207  4/29/2021 17:35      Urmila  ...      5                Good product
#
# [5 rows x 35 columns]

# %% [markdown]
# **EDA**

# %%
#length of the data
len(df)

# %%
#check shape of the data
df.shape

# %%
#preview dataset
df.head()
# Out:
#          Timestamp             Name  ... Rating                Review
# 0  3/30/2021 15:59         Jaypriya  ...      4               Nothing
# 1  3/30/2021 17:20  Mahadik simran   ...      2  Want to purchase new
# 2   4/1/2021 17:17            Sahil  ...      4               Nothing
# 3   4/1/2021 17:39           Sonali  ...      5           Its amazing
# 4   4/2/2021 17:39          Namrata  ...      4                  Good
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#           Timestamp     Name  ... Rating         Review
# 211  4/5/2021 17:39  Darshan  ...      3           Good
# 212  4/6/2021 17:39      Raj  ...      4  Extermly good
# 213  4/7/2021 17:39    Sonam  ...      4       wow.....
# 214  4/8/2021 17:39    Kajal  ...      4   Good overall
# 215  4/9/2021 17:39    Naman  ...      4        Nothing
#
# [5 rows x 35 columns]

# %%
#renaming columns
df.rename(columns ={
                      
                      'howoften': 'how_often_buy', 
                      'Changecell': 'Change_cell',
                      'Uselaptop' : 'use_laptop',
                      'Readlaunches' : 'Read_product_launches',
                    'Trynewproduct' : 'Try_new_products',
                    'Type': 'Type_of_the_product',
                    'Brand(HomeAppliances)' : 'Brand_of_HomeAppliances',
                    'Brand(ITDevices)' : 'Brand_of_ITdevices',
                    'Brand(MobileDevices)' : 'Brand_of_MobileDevices',
                    'Price(HomeAppliances)' : 'Price_of_HomeAppliances',
                    'Price(ITDevices)' : 'Price_of_ITDevices',
                    'Price(MobileDevices)' : 'Price_of_MobileDevices',
                    'Time ' : 'Which_time_prefer',
                    'Where' : 'Where_do_you_prefer',
                    'Compareprices' : 'Compare_prices',
                    'Timespend(10,000 - 30,000)' : 'Timespend_on_10,000-30,000',
                    'Timespend(30,000 - 50,000)' : 'Timespend_on_30,000-50,000',
                    'Timespend(50,000 - 70,000)' : 'Timespend_on_50,000-70,000',
                    'Timespend(70,000 - 1,00,000)' : 'Timespend_on_70,000-1,00,000',
                    'Yearlyspending' : 'Yearly_spendings',
                    'Productfeatures' : 'Product_features',
                    'Easeofuse' : 'Ease_of_use',
                    'Recommendationfromsomeone' : 'Recommendation_from_someone',
                    'Salespersonrecommendation' : 'Sales_person_recommendation',
                    'NoUseproduct' :'No_use_product'
                     },inplace=True
                )

# %% [markdown]
# **Dropping the Timestamp and Name column**

# %%
df.drop('Timestamp',axis=1,inplace=True)

# %%
df.drop('Name', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           216 non-null    object
#  1   howoften                      216 non-null    object
#  2   Changecell                    216 non-null    object
#  3   Uselaptop                     216 non-null    object
#  4   Readlaunches                  216 non-null    object
#  5   Trynewproduct                 216 non-null    object
#  6   Type                          216 non-null    object
#  7   Product                       216 non-null    object
#  8   Item                          216 non-null    object
#  9   Brand(HomeAppliances)         216 non-null    object
#  10  Brand(ITDevices)              216 non-null    object
#  11  Brand(MobileDevices)          216 non-null    object
# ...

# %%
df.sample(10)
# Out:
#               Age how_often_buy  ... Rating         Review
# 26          18-25  Occasionally  ...      4    Amazing one
# 172         35-50  Occasionally  ...      5           Good
# 133  50 and above  Occasionally  ...      4  Nice products
# 4           25-35     Regularly  ...      4           Good
# 185         25-35  Occasionally  ...      4           Nice
# 195         18-25     Regularly  ...      4        Thank u
# 171         25-35     Regularly  ...      3        Average
# 140         25-35     Regularly  ...      4        So good
# 139         25-35     Regularly  ...      4           Good
# 198         18-25  Occasionally  ...      4           Nice
#
# [10 rows x 33 columns]

# %%
#Check the number of rows and columns
rows,columns=df.shape
print('Number of rows: ',rows)
print('Number of columns: ',columns)
# Out:
# Number of rows:  216
# Number of columns:  33

# %% [markdown]
# **Data types of columns**

# %%
df.dtypes
# Out:
# Age                             object
# how_often_buy                   object
# Change_cell                     object
# use_laptop                      object
# Read_product_launches           object
# Try_new_products                object
# Type_of_the_product             object
# Product                         object
# Item                            object
# Brand_of_HomeAppliances         object
# Brand_of_ITdevices              object
# Brand_of_MobileDevices          object
# Price_of_HomeAppliances         object
# Price_of_ITDevices              object
# Price_of_MobileDevices          object
# Time                            object
# Where_do_you_prefer             object
# Compare_prices                  object
# Research                        object
# Timespend_on_10,000-30,000      object
# Timespend_on_30,000-50,000      object
# Timespend_on_50,000-70,000      object
# Timespend(70,000 - 1,00,000)    object
# Yearly_spendings                object
# ...

# %%
df.describe()
# Out:
#            Rating
# count  216.000000
# mean     4.152778
# std      0.632302
# min      2.000000
# 25%      4.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
df.describe(include=['object'])
# Out:
#           Age how_often_buy  ...          No_use_product Review
# count     216           216  ...                     216    215
# unique      4             2  ...                       4     73
# top     18-25     Regularly  ...  Sell on as second-hand   Good
# freq       84           117  ...                     126     45
#
# [4 rows x 32 columns]

# %% [markdown]
# **Missing Data**

# %%
missing=df.isna().sum().sort_values(ascending=False)
missing.plot.bar(figsize=(10,6))
plt.xlabel('Columns with missing values')
plt.ylabel('Count')
plt.show()

# %%
missing
# Out:
# Review                          1
# Type_of_the_product             0
# Price_of_HomeAppliances         0
# Brand_of_MobileDevices          0
# Brand_of_ITdevices              0
# Brand_of_HomeAppliances         0
# Item                            0
# Product                         0
# Try_new_products                0
# Price_of_MobileDevices          0
# Read_product_launches           0
# use_laptop                      0
# Change_cell                     0
# howoften                        0
# Age                             0
# Name                            0
# Price_of_ITDevices              0
# Time                            0
# Rating                          0
# Factors                         0
# No_use_product                  0
# Sales_person_recommendation     0
# Recommendation_from_someone     0
# Warranty                        0
# Ease_of_use                     0
# Product_features                0
# Yearly_spendings                0
# ...

# %%
#filling missing data
df=df.fillna(method='ffill')
df
# Out:
#        Age how_often_buy  ... Rating                Review
# 0    18-25  Occasionally  ...      4               Nothing
# 1    18-25  Occasionally  ...      2  Want to purchase new
# 2    25-35     Regularly  ...      4               Nothing
# 3    18-25  Occasionally  ...      5           Its amazing
# 4    25-35     Regularly  ...      4                  Good
# ..     ...           ...  ...    ...                   ...
# 211  25-35     Regularly  ...      3                  Good
# 212  18-25  Occasionally  ...      4         Extermly good
# 213  25-35     Regularly  ...      4              wow.....
# 214  18-25  Occasionally  ...      4          Good overall
# 215  25-35  Occasionally  ...      4               Nothing
#
# [216 rows x 33 columns]

# %% [markdown]
# **Finding Duplicate values**

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# Length: 216, dtype: bool

# %%
#replacing data
df['Age']=df['Age'].replace({'18-25': 0,'25-35' : 1,'35-50' : 2, '50 and above': 3 })

# %%
df['Type_of_the_product'].value_counts()
# Out:
# New            162
# Refurbished     54
# Name: Type_of_the_product, dtype: int64

# %%
fig = plt.figure(figsize = (10,7))
df['Type_of_the_product'].hist(bins =40, color='green');
plt.title("Which type of product sells the most?", fontsize=20)
plt.show()

# %%
df['how_often_buy'].value_counts()
# Out:
# Regularly       117
# Occasionally     99
# Name: how_often_buy, dtype: int64

# %%
fig = plt.figure(figsize = (10,7));
sns.countplot(data=df , x = 'how_often_buy', color = 'Red', palette='bone');
plt.title("How often people buy Electronic Products?" ,fontsize=20)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# Home appliances                                68
# Mobile devices                                 63
# IT Devices                                     47
# IT Devices, Mobile devices                     17
# Home appliances, Mobile devices                11
# Home appliances, IT Devices, Mobile devices     7
# Home appliances, IT Devices                     2
# Earphone                                        1
# Name: Product, dtype: int64

# %%
df['Product'].nunique()
# Out:
# 8

# %%
df['Product'].value_counts().plot(kind='barh',figsize=(15,10))
plt.title("The most sold product in different categories",fontsize=20)
plt.show()

# %%
df['Item'].value_counts()
# Out:
# Smartphone                                                                 60
# Laptop                                                                     27
# Refrigerator                                                               25
# Television                                                                 23
# Desktop                                                                    15
# Air conditioners                                                           15
# Smartphone, Refrigerator                                                    6
# Oven                                                                        4
# Television, Laptop, Smartphone, Desktop                                     4
# Television, Laptop                                                          3
# Earphones                                                                   3
# Smartphone, Desktop                                                         2
# ...

# %%
df['Item'].nunique()
# Out:
# 36

# %%
df['Item'].value_counts().plot(kind='barh',figsize=(15,10))
plt.title("Items" ,fontsize=20)
plt.show()

# %%
df['Brand_of_HomeAppliances'].value_counts(ascending=True)
# Out:
# Kenstar        1
# Wh             1
# Sony           1
# Bajaj          2
# Godrej        24
# LG            35
# Samsung       51
# Whirlpool    101
# Name: Brand_of_HomeAppliances, dtype: int64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.countplot(x='Brand_of_HomeAppliances',data=df, palette='rainbow')
plt.title("Different Brands of Home Appliances", fontsize=20)
plt.show()

# %%
df['Brand_of_ITdevices'].value_counts()
# Out:
# Lenovo           102
# HP                49
# Dell              43
# Apple             17
# Acer               2
# Acer predator      1
# MIS                1
# Espon              1
# Name: Brand_of_ITdevices, dtype: int64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.countplot(x='Brand_of_ITdevices',data=df, palette= 'BrBG')
plt.title("Different Brands of IT Devices", fontsize=20)
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,6))
sns.countplot(x='Brand_of_MobileDevices',data=df)
plt.title("Different Brands of Mobile Devices", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,6));
df['Which_time_prefer'].value_counts().plot(kind = 'pie',shadow = True, autopct='%1.1f%%', startangle=90)
plt.title('Which time do you prefer purchasing an electronic products', fontsize=20)
plt.show();

# %%
df['Where_do_you_prefer'].value_counts()
# Out:
# Online                                                                          62
# In the exclusive brand store, In an electronics store                           49
# In an electronics store                                                         35
# Online, In an electronics store                                                 25
# Online, In the exclusive brand store, In an electronics store                   17
# Online, In the exclusive brand store                                            13
# In the exclusive brand store                                                    10
# Online, In the exclusive brand store, In an electronics store, Other sources     2
# Other sources                                                                    2
# Online, In an electronics store, Other sources                                   1
# Name: Where_do_you_prefer, dtype: int64

# %%
df['Where_do_you_prefer'].nunique()
# Out:
# 10

# %%
df['Where_do_you_prefer'].value_counts().plot(kind='barh',colormap='Set2',figsize=(15,10))
plt.title("Where do you prefer buying an electronic products?", fontsize=20)
plt.xlim(0,250)
plt.show()

# %%
plt.figure(figsize=(12,6));
df['Compare_prices'].value_counts().plot(kind = 'pie')
plt.title('Do you compare prices to make purchase decision?',fontsize=20)
plt.show();

# %%
df['Research'].value_counts()
# Out:
# Ask a friend/colleague/family member for their review if they own it, Compare them with competitive products                                                    40
# Ask a friend/colleague/family member for their review if they own it, Read online reviews                                                                       38
# Ask a friend/colleague/family member for their review if they own it, Read online reviews, Compare them with competitive products                               38
# Compare them with competitive products                                                                                                                          16
# Ask a friend/colleague/family member for their review if they own it, Read online reviews, Compare them with competitive products, Find out brand reputation    14
# Read online reviews                                                                                                                                             13
# ...

# %%
df['Research'].value_counts().plot(kind='barh',figsize=(15,8), colormap='PRGn')
plt.title("How do you research while purchasing?", fontsize=20)
plt.xlim(0,250)
plt.show()

# %%
df['Factors'].value_counts()
# Out:
# Reliability of a product, Quality of a product                                            62
# Reliability of a product, Pricing of a product, Quality of a product                      34
# Reliability of a product, Pricing of a product                                            31
# Quality of a product                                                                      23
# Reliability of a product, Services offered, Pricing of a product, Quality of a product    11
# Reliability of a product, Services offered, Quality of a product                           8
# Pricing of a product, Quality of a product                                                 7
# Services offered, Pricing of a product                                                     6
# Reliability of a product                                                                   6
# Pricing of a product                                                                       6
# ...

# %%
from matplotlib.pyplot import figure, show
df['Factors'].value_counts().plot(kind='barh',figsize=(10,6), colormap='PiYG')
plt.title("Which factors will affect the most?", fontsize=20)
plt.show()

# %%
sns.set()
plt.figure(figsize=(12,6))
sns.countplot(x='Yearly_spendings', hue = 'Age',data=df, color = 'purple')
plt.title("Yearly spends on an electronic products", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='Rating',hue='Brand_of_HomeAppliances', palette='Pastel1');
plt.title('Ratings of Home Appliances', fontsize=20)
plt.show()

# %%
df.plot(x = "Brand_of_ITdevices", y ="Rating" ,kind="scatter", figsize = (10,6))
plt.title("Ratings of IT Devices", fontsize=20)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.jointplot(data=df, x='Rating',y='Brand_of_MobileDevices', kind='scatter');
plt.show()

# %%
px.histogram(df, x='Age', color='Price_of_HomeAppliances', nbins=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="89aebe32-4dff-4969-baf9-ccbade73da70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89aebe32-4dff-4969-baf9-ccbade73da70")) {
#                     Plotly.newPlot(
#                         '89aebe32-4dff-4969-baf9-ccbade73da70',
# ...

# %%
px.bar(df, x='Age', color='Price_of_ITDevices', barmode="group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="568da50c-f697-42c7-8741-cfc5b3aa3d2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("568da50c-f697-42c7-8741-cfc5b3aa3d2c")) {
#                     Plotly.newPlot(
#                         '568da50c-f697-42c7-8741-cfc5b3aa3d2c',
# ...

# %%
px.bar(df, x='Age', color='Price_of_MobileDevices')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5a2119bf-f388-4001-a953-57565b97b787" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a2119bf-f388-4001-a953-57565b97b787")) {
#                     Plotly.newPlot(
#                         '5a2119bf-f388-4001-a953-57565b97b787',
# ...

# %%
fig,ax=plt.subplots(ncols=2,nrows=4,figsize=(15,20))

df['Change_cell'].value_counts().plot.pie(ax=ax[0,0], autopct="%.1f%%")
sns.countplot(x='Change_cell', hue="Age", data=df,ax=ax[0,1], palette='pastel')

df['use_laptop'].value_counts().plot.pie(ax=ax[1,0], autopct="%.1f%%")
sns.countplot(x='use_laptop', hue="Age", data=df,ax=ax[1,1], palette='cubehelix')

df['Read_product_launches'].value_counts().plot.pie(ax=ax[2,0], autopct="%.1f%%")
sns.countplot(x='Read_product_launches', hue="Age", data=df,ax=ax[2,1], palette='rocket')

df['Try_new_products'].value_counts().plot.pie(ax=ax[3,0], autopct="%.1f%%")
sns.countplot(x='Try_new_products', hue="Age", data=df,ax=ax[3,1],palette='flare')
plt.legend()
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=4,figsize=(15,20))

df['Product_features'].value_counts().plot.pie(ax=ax[0,0], autopct="%.1f%%")
sns.countplot(x='Product_features', hue="Age", data=df,ax=ax[0,1], palette='Set2')

df['Ease_of_use'].value_counts().plot.pie(ax=ax[1,0], autopct="%.1f%%")
sns.countplot(x='Ease_of_use', hue="Age", data=df,ax=ax[1,1], palette='Set3')

df['Warranty'].value_counts().plot.pie(ax=ax[2,0], autopct="%.1f%%")
sns.countplot(x='Warranty', hue="Age", data=df,ax=ax[2,1],palette='muted')

df['Recommendation_from_someone'].value_counts().plot.pie(ax=ax[3,0], autopct="%.1f%%")
sns.countplot(x='Recommendation_from_someone', hue="Age", data=df,ax=ax[3,1],palette='Dark2_r')

df['Sales_person_recommendation'].value_counts().plot.pie(ax=ax[3,0], autopct="%.1f%%")
sns.countplot(x='Sales_person_recommendation', hue="Age", data=df,ax=ax[3,1],palette='Set1')

plt.legend()
plt.show()
